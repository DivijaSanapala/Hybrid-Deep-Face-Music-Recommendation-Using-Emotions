# %% [markdown]
# <a href="https://colab.research.google.com/github/DivijaSanapala/Hybrid-Deep-Face-Music-Recommendation-Using-Emotions/blob/main/Music_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
pip install deepface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 65 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 11.1 MB/s
# ...
#      |████████████████████████████████| 87 kB 6.3 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=c302dcb3dc7f0abee69f2e233eca0e0759f01571bd318dc06acf938db9a15ede
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
img = cv2.imread('happy_boy.jpg')

# %%
import numpy

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 78.4MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 100%|██████████| 539M/539M [00:06<00:00, 89.3MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# 100%|██████████| 537M/537M [00:14<00:00, 36.7MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# ...

# %%
predictions
# Out:
# {'emotion': {'angry': 4.318765895548766e-15,
#   'disgust': 1.3027060671944495e-18,
#   'fear': 1.1641985986354797e-09,
#   'happy': 100.0,
#   'sad': 2.1416666996700723e-11,
#   'surprise': 3.628059007734774e-10,
#   'neutral': 3.6194474972717217e-06},
#  'dominant_emotion': 'happy',
#  'region': {'x': 192, 'y': 177, 'w': 418, 'h': 418},
#  'age': 22,
#  'gender': 'Man',
#  'race': {'asian': 0.003571631168597378,
#   'indian': 0.027856999076902866,
#   'black': 0.0005082378265797161,
#   'white': 86.19005084037781,
#   'middle eastern': 8.585499227046967,
#   'latino hispanic': 5.192514508962631},
#  'dominant_race': 'white'}

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
  cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions['dominant_emotion'], (50,50),font,3,(0,255,0),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sad_girl.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.81it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 3.822307661175728,
#   'disgust': 0.7593185175210238,
#   'fear': 3.4688517451286316,
#   'happy': 0.00044905164031661116,
#   'sad': 91.55592918395996,
#   'surprise': 0.009595636947778985,
#   'neutral': 0.3835515817627311},
#  'dominant_emotion': 'sad',
#  'region': {'x': 75, 'y': 40, 'w': 58, 'h': 58},
#  'age': 31,
#  'gender': 'Woman',
#  'race': {'asian': 3.4212738275527954,
#   'indian': 13.712866604328156,
#   'black': 0.8374860510230064,
#   'white': 19.29958015680313,
#   'middle eastern': 40.41755199432373,
#   'latino hispanic': 22.311237454414368},
#  'dominant_race': 'middle eastern'}

# %%
predictions['dominant_emotion']
# Out:
# 'sad'

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
  cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions['dominant_emotion'], (0,55),font,3,(0,255,0),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('angry_boy.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.82it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 98.66128555901561,
#   'disgust': 1.202283778177725,
#   'fear': 0.05676879420243467,
#   'happy': 4.522416915170757e-05,
#   'sad': 0.07174174379694424,
#   'surprise': 0.007441067725865481,
#   'neutral': 0.0004332018110201842},
#  'dominant_emotion': 'angry',
#  'region': {'x': 85, 'y': 55, 'w': 59, 'h': 59},
#  'age': 21,
#  'gender': 'Man',
#  'race': {'asian': 3.0927102993554056,
#   'indian': 7.492879479699104,
#   'black': 1.3674694928508695,
#   'white': 37.435146417328504,
#   'middle eastern': 21.96052652362147,
#   'latino hispanic': 28.65126899786407},
#  'dominant_race': 'white'}

# %%
predictions['dominant_emotion']
# Out:
# 'angry'

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
  cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions['dominant_emotion'], (30,50),font,3,(0,255,0),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
  cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0),2)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, predictions['dominant_emotion'], (50,50),font,3,(0,255,0),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
#Music Recommendation

# %%
import pandas as pd

# %%
data=pd.read_csv('data.csv.zip',compression='zip')
data
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.utils import shuffle

# %%
data.drop_duplicates(inplace=True,subset=['name'])

# %%
name=data['name']

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
col_features = ['danceability', 'energy', 'valence', 'loudness']
X = MinMaxScaler().fit_transform(data[col_features])
kmeans = KMeans(init="k-means++", n_clusters=2, random_state=15).fit(X)
data['kmeans'] = kmeans.labels_

# %%
data['song_name']=name
data
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921         0.982
# 1        0.9630  1921         0.732
# 2        0.0394  1921         0.961
# 3        0.1650  1921         0.967
# 4        0.2530  1921         0.957
# ...         ...   ...           ...
# 170646   0.5220  2020         0.204
# 170647   0.0838  2020         0.974
# 170649   0.7340  2020         0.206
# 170650   0.6370  2020         0.101
# 170652   0.6420  2020         0.132
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
cluster=data.groupby(by=data['kmeans'])
y=data.pop('kmeans')
x=data.drop(columns=['name','artists','id','release_date','song_name'])
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
# !pip install lightgbm
from lightgbm import LGBMClassifier
model=LGBMClassifier().fit(x_train,y_train)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
data
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921         0.982
# 1        0.9630  1921         0.732
# 2        0.0394  1921         0.961
# 3        0.1650  1921         0.967
# 4        0.2530  1921         0.957
# ...         ...   ...           ...
# 170646   0.5220  2020         0.204
# 170647   0.0838  2020         0.974
# 170649   0.7340  2020         0.206
# 170650   0.6370  2020         0.101
# 170652   0.6420  2020         0.132
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
model.score(x_train,y_train)
# Out:
# 0.9992417288582033

# %%
model.score(x_test,y_test)
# Out:
# 0.9948817719245735

# %%
import lightgbm
import matplotlib.pyplot as plt
ax = lightgbm.plot_importance(model, max_num_features=10, figsize=(6,6))
plt.show()

# %%
# Testing the static images

# %%
df=cluster.apply(lambda x: x.sort_values(["popularity"],ascending=False))
df.reset_index(level=0, inplace=True)
from tensorflow.keras.utils import img_to_array
import imutils
from keras.models import load_model
import numpy as np
import cv2
detection_model_path = 'haarcascade_frontalface_default.xml'
face_detection = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
EMOTIONS = ["happy","sad"]

# %%
face_detection = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
if predictions['dominant_emotion']=='sad' or predictions['dominant_emotion']=='angry'or predictions['dominant_emotion']=='fear'or predictions['dominant_emotion']=='disgust':
    emotion_code=0
else:
    emotion_code=1

# %%
happy_set=[]
h_set=[]
sad_set=[]
s_set=[]
def get_results(emotion_code):
  #NUM_RECOMMEND=10
  if emotion_code==1:
      happy_set.append(df[df['kmeans']==1]['song_name'].head(10))
     # h_set.append(df[df['kmeans']==1]['song_name'].head(0))
      return pd.DataFrame(happy_set).T
  else:
      sad_set.append(df[df['kmeans']==0]['song_name'].head(10))
     # s_set.append(df[df['kmeans']==1]['song_name'].head(0))
      return pd.DataFrame(sad_set).T
output_results = get_results(emotion_code)
print(output_results)
if emotion_code == 0:
    print('emotion detected is SAD')
else:
    print('emotion detected is HAPPY')
# Out:
#                               song_name
# 19611                            Dakiti
# 19620        Lonely (with benny blanco)
# 19623                you broke me first
# 19619                           Heather
# 19633                            Wonder
# 19413                 Someone You Loved
# 19645  death bed (coffee for your head)
# 19636      Mood Swings (feat. Lil Tjay)
# 19210              lovely (with Khalid)
# 19207                      Lucid Dreams
# emotion detected is SAD

# %%
import urllib.request
import re
import webbrowser
# !pip install pywhatkit
#import pywhatkit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 59 kB 5.0 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 132 kB 36.4 MB/s
# ...
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36614 sha256=a28a0799b18fa33d1ee657894684270a22ec3a0583140f902982b6adf648a574
#   Stored in directory: /root/.cache/pip/wheels/23/db/81/a14b5eca81ccb97c15e5bbea8d5394b8cbf6b36451d89dd648
# ...
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11081 sha256=1f23e05f681f034ed0e1604f53a515930aabaade24a3437bbf2e3e713ed98f83
# ...

# %%
import random
search_query = "https://www.youtube.com/results?search_query="
if emotion_code == 1:
  #r1 = random.randint(0, 10)
  sname = "Mood"
  #sname = data.loc[19606].at["song_name"]
else:
  #r1 = random.randint(0, 10)
  sname = "Dakiti"

#sname = "Mood (feat. iann dior)"
#r1 = random.randint(0, 10)
#sname = data.loc[r1].at["song_name"]
#sname = df[df['kmeans']==0]['song_name']


print(sname)
#sname="Someone you love"
#sname = output_results[pd.DataFrame(happy_set).T]
s_name = sname.replace(" ", "+")
print(s_name)
# Out:
# Dakiti
# Dakiti

# %%
html = urllib.request.urlopen(search_query+s_name)
video_ids = re.findall(r"watch\?v=(\S{11})", html.read().decode())
print(video_ids)

result_link = "https://www.youtube.com/watch?v=" + video_ids[0]
#print(result_link)
# webbrowser.open_new_tab(result_link)
urllib.request.urlopen(result_link)
#pywhatkit.playonyt(result_link)
# Out:
# ['TmKh7lAwnBI', 'YwtHba4jJdw', 'UZKrPb5YZE0', '-GHKp0feIaw', 'Eg_SaxQJwfw', 'b-HETCLwrU8', 'Nhi2Sd1ZZ18', 'qVNZxGl_VFo', 'Yvl1ZI_8hwQ', 'x4at2O0dWvI', 'HO6EB0Iqxjo', 'ayd3yWr4tqU', 'jM53ZkRElLk', 'o1lKMrLat_I', 'Wa2ZCwkArv8', 'doLMt10ytHY', 'TJwWFoP4WUY', 'w2C6RhQBYlg', 'CVVIn2kNWvs', 'XXYlFuWEuKI', 'FjbRS288Uh4', 'qQsEHIb79-M', 'ZAPdo_iDnL4', 'AMAomoFzcyo', 'TmKh7lAwnBI', 'TmKh7lAwnBI', 'Bv1jALmLfQQ', 'J1tofJaoa9w', 'LDrx0_orkkQ', '6WpEhxu9Kn0', 'doLMt10ytHY', 'f5omY8jVrSM', 'ZRnp5vwF5yA', 'LxOTsiV4tkQ', 'heuvkSOE2_4', 'cyiKTc4XQlI']

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(video_ids[0])

# %%
#Testing Real time image

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
im = cv2.imread('photo.jpg')

# %%
plt.imshow(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))

# %%
pred = DeepFace.analyze(im)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:04<00:00,  1.21s/it]

# %%
pred['dominant_emotion']
# Out:
# 'happy'

# %%
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
  cv2.rectangle(im, (x,y), (x+w, y+h), (255,0,0),2)
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(im, pred['dominant_emotion'], (50,50),font,3,(0,255,0),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))

# %%
if pred['dominant_emotion']=='sad' or pred['dominant_emotion']=='angry' or pred['dominant_emotion']=='fear'or pred['dominant_emotion']=='disgust':
    emotion_code=0
else:
    emotion_code=1

# %%
def get_results(emotion_code):
  NUM_RECOMMEND=10
  happy_set=[]
  sad_set=[]
  if emotion_code==1:
      happy_set.append(df[df['kmeans']==1]['song_name'].head(NUM_RECOMMEND))
      return pd.DataFrame(happy_set).T
  else:
      sad_set.append(df[df['kmeans']==0]['song_name'].head(NUM_RECOMMEND))
      return pd.DataFrame(sad_set).T

output_results = get_results(emotion_code)
print(output_results)
if emotion_code == 0:
    print('emotion detected is SAD')
else:
    print('emotion detected is HAPPY')
# Out:
#                                      song_name
# 19606                   Mood (feat. iann dior)
# 19608          WAP (feat. Megan Thee Stallion)
# 19616                          Blinding Lights
# 19612                  What You Know Bout Love
# 19610                                positions
# 19615           Holy (feat. Chance The Rapper)
# 19607  For The Night (feat. Lil Baby & DaBaby)
# 19655                Head & Heart (feat. MNEK)
# 19407                         Watermelon Sugar
# 19720                         Relación - Remix
# emotion detected is HAPPY

# %%
import random
search_query = "https://www.youtube.com/results?search_query="
if emotion_code == 1:
  #r1 = random.randint(0, 10)
  sname = "Mood"
  #sname = data.loc[19606].at["song_name"]
else:
  #r1 = random.randint(0, 10)
  sname = "Dakiti"

#sname = "Mood (feat. iann dior)"
#r1 = random.randint(0, 10)
#sname = data.loc[r1].at["song_name"]
#sname = df[df['kmeans']==0]['song_name']


print(sname)
#sname="Someone you love"
#sname = output_results[pd.DataFrame(happy_set).T]
s_name = sname.replace(" ", "+")
print(s_name)
# Out:
# Mood
# Mood

# %%
html = urllib.request.urlopen(search_query+s_name)
video_ids = re.findall(r"watch\?v=(\S{11})", html.read().decode())
print(video_ids)

result_link = "https://www.youtube.com/watch?v=" + video_ids[0]
#print(result_link)
# webbrowser.open_new_tab(result_link)
urllib.request.urlopen(result_link)
#pywhatkit.playonyt(result_link)
# Out:
# ['GrAchTdepsU', 'nMVFSwfV6wk', 'yI0gcR0wnt4', 'XlYZNo4Keq0', 'GGtTndgkcCI', 'vYVLNTg10tw', 'fHUXk9Y9Z0U', 'Y98KZQ05R_c', 'M56T7SkqOqo', 'f1e8Ok4BmeU', 'Ivs9FG9ZkZA', 'TLMPwMVT75Q', 'eHRscrFd9_E', 'toc8wPwqjfA', '8RT3174a3mQ', '5ekVQ_cSBY0', '4VkWsBukAWI', 'hhY1cwxQZv0', 'r-Q6UrrxF4U', 'ZC9HQnvD6rQ', '_j77Toa85KM', '2Xa6rYwURgo', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', '4iDwk4n39R0', 'mhsckf9XFqc', 'KWxENcTAe1A', 'Tpv5ibeHdcE', 'iY3VeMzcpgs', 'TwLs_c-2E2M', 'j6hwb1IE0xk', 'VTNNaE0Y_Pk', 'N_O4u_nDbGs', 'f1J4dRTMy9A', 'GrAchTdepsU', 'GrAchTdepsU', '83xBPCw5hh4', 'Qq7xrY0dLrE', '-LtJlHwgWos', '-LtJlHwgWos', '-LtJlHwgWos', '-LtJlHwgWos', '-LtJlHwgWos', '-LtJlHwgWos', '-LtJlHwgWos', '-LtJlHwgWos', '-LtJlHwgWos', 'HJStoGzby00', 'JOHN4EnFqAU', '2fvw0TkENHM']

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(video_ids[0])

# %%
import urllib.request
import re
import webbrowser
# !pip install pywhatkit
#import pywhatkit

# %%
search_query = "https://www.youtube.com/results?search_query="
song_name_query = "pasoori"
# song_name = output_results[song_name].iloc[0]

html = urllib.request.urlopen(search_query+song_name_query)
video_ids = re.findall(r"watch\?v=(\S{11})", html.read().decode())
print(video_ids)

result_link = "https://www.youtube.com/watch?v=" + video_ids[0]
#print(result_link)
# webbrowser.open_new_tab(result_link)
urllib.request.urlopen(result_link)
#pywhatkit.playonyt(result_link)

# %%
search_query = "https://www.youtube.com/results?search_query="
song_name_query = "pasoori"
# song_name = output_results[song_name].iloc[0]

html = urllib.request.urlopen(search_query+song_name_query)
video_ids = re.findall(r"watch\?v=(\S{11})", html.read().decode())
print(video_ids)

result_link = "https://www.youtube.com/watch?v=" + video_ids[0]
print(result_link)
# webbrowser.open_new_tab(result_link)
#urllib.request.urlopen(result_link)
#pywhatkit.playonyt(result_link)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(video_ids[0])
